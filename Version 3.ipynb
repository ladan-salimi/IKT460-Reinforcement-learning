# %%
#PPo based constant form question:Similar env with reinforce

# %%
import pandas as pd
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

df = pd.read_excel('knowledge_base1.xlsx')

FEATURES = ["Hair", "Feathers", "Eggs", "Milk", "Airborne", "Aquatic", "Predator", "Toothed",
            "Backbone", "Breathes", "Venomous", "Fins", "Nlegs_0", "Nlegs_2", "Nlegs_4",
            "Nlegs_5", "Nlegs_6", "Nlegs_8", "Tail", "Domestic", "Catsize",
            "Mammal", "Bird", "Reptile", "Fish", "Amphibian", "Insect", "Invertebrate"]

animal_features = df.iloc[:, 1:].values
NUM_FEATURES = len(FEATURES)
print("Dataset loaded. Number of features:", NUM_FEATURES)
# Out:
# Dataset loaded. Number of features: 28

# %%
class Animal20QEnv:
    def __init__(self, animal_features, max_steps=20):
        self.animal_features = animal_features
        self.num_animals = len(animal_features)
        self.num_features = animal_features.shape[1]
        self.max_steps = max_steps

    def reset(self):
        self.target_idx = random.randint(0, self.num_animals - 1)
        self.remaining_animals = list(range(self.num_animals))
        self.asked_features = set()
        self.steps = 0
        self.state = np.zeros(self.num_features, dtype=np.float32)
        return self.state

    def step(self, feature_idx):
        previous_remaining = len(self.remaining_animals)
        answer = self.animal_features[self.target_idx][feature_idx]
        self.remaining_animals = [idx for idx in self.remaining_animals if self.animal_features[idx][feature_idx] == answer]
        self.state[feature_idx] = answer
        self.steps += 1
        done = self.steps >= self.max_steps

        eliminated = previous_remaining - len(self.remaining_animals)
        reward = eliminated
        if eliminated >= 10:
            reward += 10
        if feature_idx in self.asked_features:
            reward -= 5
        else:
            self.asked_features.add(feature_idx)

        if done:
            guessed_idx = self.guess_animal()
            reward += 50 if guessed_idx == self.target_idx else -10

        return self.state.copy(), reward, done

    def guess_animal(self):
        if np.all(self.state == 0):
            return random.choice(self.remaining_animals)
        match_scores = self.animal_features @ self.state
        return np.argmax(match_scores)

# %%
class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.shared = nn.Sequential(
            nn.Linear(state_dim, 128), nn.ReLU(),
            nn.Linear(128, 128), nn.ReLU())
        self.actor = nn.Linear(128, action_dim)
        self.critic = nn.Linear(128, 1)

    def forward(self, x):
        shared = self.shared(x)
        return self.actor(shared), self.critic(shared)

class PPO:
    def __init__(self, state_dim, action_dim):
        self.model = ActorCritic(state_dim, action_dim)
        self.optimizer = optim.Adam(self.model.parameters(), lr=1e-3)
        self.gamma = 0.99
        self.eps_clip = 0.2

    def select_action(self, state):
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        logits, _ = self.model(state)
        probs = torch.softmax(logits, dim=-1)
        dist = torch.distributions.Categorical(probs)
        action = dist.sample()
        return action.item(), dist.log_prob(action)

    def train_step(self, states, actions, rewards, log_probs, next_states, dones):
        states = torch.tensor(states, dtype=torch.float32)
        actions = torch.tensor(actions)
        rewards = torch.tensor(rewards, dtype=torch.float32)
        log_probs = torch.stack(log_probs)
        dones = torch.tensor(dones, dtype=torch.float32)

        _, next_values = self.model(torch.tensor(next_states, dtype=torch.float32))
        _, values = self.model(states)
        values = values.squeeze()
        next_values = next_values.squeeze()

        returns = rewards + self.gamma * next_values * (1 - dones)
        advantages = returns - values

        new_logits, _ = self.model(states)
        new_probs = torch.softmax(new_logits, dim=-1)
        new_dist = torch.distributions.Categorical(new_probs)
        new_log_probs = new_dist.log_prob(actions)

        ratio = torch.exp(new_log_probs - log_probs.detach())
        surr1 = ratio * advantages
        surr2 = torch.clamp(ratio, 1 - self.eps_clip, 1 + self.eps_clip) * advantages
        loss = -torch.min(surr1, surr2).mean() + (returns - values).pow(2).mean()

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
env = Animal20QEnv(animal_features=animal_features)
ppo = PPO(state_dim=NUM_FEATURES, action_dim=NUM_FEATURES)

episodes = 15000
success_log = []

for ep in range(episodes):
    state = env.reset()
    done = False
    total_reward = 0
    log_probs = []
    states = []
    actions = []
    rewards = []
    next_states = []
    dones = []
    
    episode_questions = []  # ✅ Store constant-form questions

    while not done:
        action, log_prob = ppo.select_action(state)
        next_state, reward, done = env.step(action)

        # ✅ Constant-form question
        feature_name = FEATURES[action]
        question = f"Does the animal have {feature_name.replace('_', ' ').lower()}?"
        episode_questions.append(question)

        states.append(state)
        actions.append(action)
        rewards.append(reward)
        next_states.append(next_state)
        dones.append(done)
        log_probs.append(log_prob)

        state = next_state
        total_reward += reward

    ppo.train_step(states, actions, rewards, log_probs, next_states, dones)
    success = int(env.guess_animal() == env.target_idx)
    success_log.append(success)

    if (ep + 1) % 50 == 0:
        avg_success = np.mean(success_log[-50:])
        print(f"\nEpisode {ep + 1}, Average Success Rate: {avg_success:.2f}")
        print("Sample Questions:")
        for q in episode_questions[:5]:  # Show first 5
            print(" -", q)
# Out:
# Episode 50, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have hair?
#  - Does the animal have aquatic?
#  - Does the animal have tail?
#  - Does the animal have nlegs 8?
#  - Does the animal have nlegs 6?
#
# Episode 100, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have feathers?
#  - Does the animal have nlegs 4?
#  - Does the animal have predator?
#  - Does the animal have nlegs 4?
#
# Episode 150, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have nlegs 6?
#  - Does the animal have milk?
#  - Does the animal have milk?
#  - Does the animal have reptile?
#  - Does the animal have bird?
#
# Episode 200, Average Success Rate: 0.10
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have nlegs 4?
#  - Does the animal have nlegs 2?
#  - Does the animal have eggs?
#  - Does the animal have eggs?
#
# Episode 250, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have toothed?
#  - Does the animal have domestic?
#  - Does the animal have toothed?
#  - Does the animal have predator?
#
# Episode 300, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have nlegs 2?
#  - Does the animal have eggs?
#  - Does the animal have fins?
#  - Does the animal have nlegs 4?
#
# Episode 350, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 4?
#  - Does the animal have milk?
#  - Does the animal have predator?
#
# Episode 400, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have fins?
#  - Does the animal have backbone?
#  - Does the animal have breathes?
#  - Does the animal have hair?
#  - Does the animal have nlegs 0?
#
# Episode 450, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have eggs?
#  - Does the animal have breathes?
#  - Does the animal have predator?
#  - Does the animal have nlegs 4?
#
# Episode 500, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have mammal?
#  - Does the animal have eggs?
#  - Does the animal have tail?
#  - Does the animal have predator?
#
# Episode 550, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have aquatic?
#  - Does the animal have aquatic?
#  - Does the animal have aquatic?
#  - Does the animal have feathers?
#
# Episode 600, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have breathes?
#  - Does the animal have tail?
#  - Does the animal have toothed?
#  - Does the animal have aquatic?
#
# Episode 650, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have fish?
#  - Does the animal have domestic?
#  - Does the animal have milk?
#  - Does the animal have airborne?
#
# Episode 700, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have backbone?
#  - Does the animal have backbone?
#  - Does the animal have feathers?
#  - Does the animal have toothed?
#
# Episode 750, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have toothed?
#  - Does the animal have nlegs 2?
#  - Does the animal have domestic?
#  - Does the animal have predator?
#
# Episode 800, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have hair?
#  - Does the animal have fish?
#  - Does the animal have hair?
#  - Does the animal have backbone?
#
# Episode 850, Average Success Rate: 0.08
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have tail?
#  - Does the animal have feathers?
#  - Does the animal have nlegs 0?
#  - Does the animal have nlegs 4?
#
# Episode 900, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have backbone?
#  - Does the animal have aquatic?
#  - Does the animal have nlegs 4?
#  - Does the animal have venomous?
#
# Episode 950, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have feathers?
#  - Does the animal have eggs?
#  - Does the animal have backbone?
#  - Does the animal have feathers?
#  - Does the animal have catsize?
#
# Episode 1000, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have feathers?
#  - Does the animal have nlegs 4?
#  - Does the animal have airborne?
#  - Does the animal have tail?
#  - Does the animal have nlegs 0?
#
# Episode 1050, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have nlegs 2?
#  - Does the animal have tail?
#  - Does the animal have nlegs 4?
#  - Does the animal have nlegs 2?
#
# Episode 1100, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have tail?
#  - Does the animal have toothed?
#  - Does the animal have mammal?
#  - Does the animal have mammal?
#
# Episode 1150, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have backbone?
#  - Does the animal have breathes?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 0?
#
# Episode 1200, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have predator?
#  - Does the animal have predator?
#  - Does the animal have tail?
#  - Does the animal have fish?
#
# Episode 1250, Average Success Rate: 0.10
# Sample Questions:
#  - Does the animal have eggs?
#  - Does the animal have eggs?
#  - Does the animal have tail?
#  - Does the animal have airborne?
#  - Does the animal have breathes?
#
# Episode 1300, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have nlegs 6?
#  - Does the animal have nlegs 0?
#  - Does the animal have backbone?
#  - Does the animal have predator?
#  - Does the animal have eggs?
#
# Episode 1350, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have domestic?
#  - Does the animal have nlegs 2?
#  - Does the animal have milk?
#  - Does the animal have eggs?
#
# Episode 1400, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have tail?
#  - Does the animal have predator?
#  - Does the animal have nlegs 2?
#  - Does the animal have backbone?
#
# Episode 1450, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have nlegs 4?
#  - Does the animal have backbone?
#  - Does the animal have catsize?
#  - Does the animal have nlegs 4?
#
# Episode 1500, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have aquatic?
#  - Does the animal have backbone?
#  - Does the animal have breathes?
#  - Does the animal have tail?
#
# Episode 1550, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have nlegs 4?
#  - Does the animal have aquatic?
#  - Does the animal have breathes?
#  - Does the animal have breathes?
#
# Episode 1600, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have nlegs 0?
#  - Does the animal have toothed?
#  - Does the animal have breathes?
#  - Does the animal have tail?
#  - Does the animal have nlegs 0?
#
# Episode 1650, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have hair?
#  - Does the animal have airborne?
#  - Does the animal have backbone?
#  - Does the animal have mammal?
#
# Episode 1700, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have toothed?
#  - Does the animal have nlegs 2?
#  - Does the animal have predator?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 2?
#
# Episode 1750, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have milk?
#  - Does the animal have domestic?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 4?
#
# Episode 1800, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have nlegs 2?
#  - Does the animal have tail?
#  - Does the animal have catsize?
#  - Does the animal have backbone?
#  - Does the animal have venomous?
#
# Episode 1850, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have predator?
#  - Does the animal have toothed?
#  - Does the animal have reptile?
#  - Does the animal have domestic?
#
# Episode 1900, Average Success Rate: 0.06
# Sample Questions:
#  - Does the animal have nlegs 0?
#  - Does the animal have hair?
#  - Does the animal have hair?
#  - Does the animal have nlegs 0?
#  - Does the animal have nlegs 4?
#
# Episode 1950, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have mammal?
#  - Does the animal have eggs?
#  - Does the animal have tail?
#  - Does the animal have aquatic?
#
# Episode 2000, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have breathes?
#  - Does the animal have milk?
#  - Does the animal have tail?
#  - Does the animal have aquatic?
#
# Episode 2050, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have hair?
#  - Does the animal have eggs?
#  - Does the animal have nlegs 4?
#  - Does the animal have nlegs 4?
#  - Does the animal have nlegs 4?
#
# Episode 2100, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have eggs?
#  - Does the animal have predator?
#  - Does the animal have fish?
#  - Does the animal have nlegs 4?
#
# Episode 2150, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have mammal?
#  - Does the animal have fish?
#  - Does the animal have airborne?
#  - Does the animal have tail?
#  - Does the animal have aquatic?
#
# Episode 2200, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have tail?
#  - Does the animal have hair?
#  - Does the animal have toothed?
#  - Does the animal have nlegs 4?
#
# Episode 2250, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have backbone?
#  - Does the animal have backbone?
#  - Does the animal have milk?
#  - Does the animal have nlegs 2?
#
# Episode 2300, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have mammal?
#  - Does the animal have predator?
#  - Does the animal have nlegs 2?
#  - Does the animal have catsize?
#
# Episode 2350, Average Success Rate: 0.10
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have nlegs 0?
#  - Does the animal have predator?
#  - Does the animal have eggs?
#  - Does the animal have tail?
#
# Episode 2400, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have eggs?
#  - Does the animal have mammal?
#  - Does the animal have breathes?
#  - Does the animal have predator?
#  - Does the animal have catsize?
#
# Episode 2450, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have tail?
#  - Does the animal have airborne?
#  - Does the animal have predator?
#  - Does the animal have nlegs 4?
#
# Episode 2500, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 4?
#  - Does the animal have mammal?
#  - Does the animal have aquatic?
#
# Episode 2550, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have mammal?
#  - Does the animal have airborne?
#  - Does the animal have tail?
#  - Does the animal have hair?
#  - Does the animal have milk?
#
# Episode 2600, Average Success Rate: 0.30
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have nlegs 4?
#  - Does the animal have breathes?
#  - Does the animal have predator?
#  - Does the animal have airborne?
#
# Episode 2650, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have toothed?
#  - Does the animal have predator?
#  - Does the animal have tail?
#  - Does the animal have catsize?
#  - Does the animal have feathers?
#
# Episode 2700, Average Success Rate: 0.30
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have toothed?
#  - Does the animal have milk?
#  - Does the animal have airborne?
#  - Does the animal have backbone?
#
# Episode 2750, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have catsize?
#  - Does the animal have toothed?
#  - Does the animal have airborne?
#  - Does the animal have backbone?
#
# Episode 2800, Average Success Rate: 0.34
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have predator?
#  - Does the animal have catsize?
#  - Does the animal have toothed?
#  - Does the animal have toothed?
#
# Episode 2850, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have breathes?
#  - Does the animal have predator?
#  - Does the animal have nlegs 0?
#  - Does the animal have airborne?
#
# Episode 2900, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have hair?
#  - Does the animal have breathes?
#  - Does the animal have tail?
#  - Does the animal have nlegs 8?
#
# Episode 2950, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have nlegs 4?
#  - Does the animal have eggs?
#  - Does the animal have milk?
#  - Does the animal have eggs?
#
# Episode 3000, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have aquatic?
#  - Does the animal have eggs?
#  - Does the animal have breathes?
#  - Does the animal have nlegs 0?
#
# Episode 3050, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have eggs?
#  - Does the animal have nlegs 0?
#  - Does the animal have catsize?
#  - Does the animal have eggs?
#  - Does the animal have tail?
#
# Episode 3100, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have nlegs 4?
#  - Does the animal have breathes?
#  - Does the animal have toothed?
#  - Does the animal have toothed?
#  - Does the animal have catsize?
#
# Episode 3150, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have airborne?
#  - Does the animal have hair?
#  - Does the animal have catsize?
#  - Does the animal have predator?
#
# Episode 3200, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have nlegs 4?
#  - Does the animal have eggs?
#  - Does the animal have mammal?
#  - Does the animal have aquatic?
#
# Episode 3250, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have toothed?
#  - Does the animal have predator?
#  - Does the animal have predator?
#  - Does the animal have toothed?
#
# Episode 3300, Average Success Rate: 0.32
# Sample Questions:
#  - Does the animal have eggs?
#  - Does the animal have aquatic?
#  - Does the animal have breathes?
#  - Does the animal have catsize?
#  - Does the animal have breathes?
#
# Episode 3350, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have toothed?
#  - Does the animal have domestic?
#  - Does the animal have nlegs 0?
#  - Does the animal have nlegs 2?
#
# Episode 3400, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have eggs?
#  - Does the animal have toothed?
#  - Does the animal have venomous?
#  - Does the animal have mammal?
#
# Episode 3450, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have domestic?
#  - Does the animal have breathes?
#  - Does the animal have tail?
#  - Does the animal have toothed?
#
# Episode 3500, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have nlegs 2?
#  - Does the animal have backbone?
#  - Does the animal have toothed?
#  - Does the animal have aquatic?
#  - Does the animal have breathes?
#
# Episode 3550, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have nlegs 5?
#  - Does the animal have mammal?
#  - Does the animal have airborne?
#  - Does the animal have tail?
#
# Episode 3600, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 4?
#  - Does the animal have domestic?
#  - Does the animal have breathes?
#
# Episode 3650, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have nlegs 2?
#  - Does the animal have domestic?
#  - Does the animal have eggs?
#  - Does the animal have backbone?
#  - Does the animal have tail?
#
# Episode 3700, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have nlegs 4?
#  - Does the animal have nlegs 2?
#  - Does the animal have nlegs 2?
#  - Does the animal have eggs?
#  - Does the animal have backbone?
#
# Episode 3750, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have mammal?
#  - Does the animal have breathes?
#  - Does the animal have domestic?
#  - Does the animal have mammal?
#
# Episode 3800, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have predator?
#  - Does the animal have breathes?
#  - Does the animal have airborne?
#  - Does the animal have backbone?
#
# Episode 3850, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have hair?
#  - Does the animal have nlegs 4?
#  - Does the animal have milk?
#  - Does the animal have fins?
#
# Episode 3900, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have eggs?
#  - Does the animal have milk?
#  - Does the animal have domestic?
#  - Does the animal have mammal?
#  - Does the animal have nlegs 0?
#
# Episode 3950, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have tail?
#  - Does the animal have catsize?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 2?
#
# Episode 4000, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have tail?
#  - Does the animal have nlegs 4?
#  - Does the animal have backbone?
#  - Does the animal have airborne?
#
# Episode 4050, Average Success Rate: 0.06
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have nlegs 0?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 4?
#  - Does the animal have domestic?
#
# Episode 4100, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have aquatic?
#  - Does the animal have nlegs 0?
#  - Does the animal have nlegs 4?
#  - Does the animal have aquatic?
#
# Episode 4150, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have nlegs 0?
#  - Does the animal have milk?
#  - Does the animal have backbone?
#  - Does the animal have predator?
#
# Episode 4200, Average Success Rate: 0.32
# Sample Questions:
#  - Does the animal have nlegs 0?
#  - Does the animal have eggs?
#  - Does the animal have eggs?
#  - Does the animal have mammal?
#  - Does the animal have eggs?
#
# Episode 4250, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have eggs?
#  - Does the animal have hair?
#  - Does the animal have hair?
#  - Does the animal have tail?
#  - Does the animal have nlegs 2?
#
# Episode 4300, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have predator?
#  - Does the animal have tail?
#  - Does the animal have nlegs 4?
#  - Does the animal have nlegs 4?
#
# Episode 4350, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have eggs?
#  - Does the animal have backbone?
#  - Does the animal have tail?
#  - Does the animal have milk?
#
# Episode 4400, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have predator?
#  - Does the animal have aquatic?
#  - Does the animal have breathes?
#  - Does the animal have nlegs 4?
#
# Episode 4450, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have feathers?
#  - Does the animal have predator?
#  - Does the animal have nlegs 0?
#  - Does the animal have backbone?
#  - Does the animal have eggs?
#
# Episode 4500, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have eggs?
#  - Does the animal have nlegs 0?
#  - Does the animal have toothed?
#  - Does the animal have airborne?
#  - Does the animal have mammal?
#
# Episode 4550, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have eggs?
#  - Does the animal have predator?
#  - Does the animal have nlegs 0?
#  - Does the animal have toothed?
#  - Does the animal have eggs?
#
# Episode 4600, Average Success Rate: 0.30
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have breathes?
#  - Does the animal have hair?
#  - Does the animal have nlegs 4?
#  - Does the animal have milk?
#
# Episode 4650, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have breathes?
#  - Does the animal have nlegs 4?
#  - Does the animal have milk?
#  - Does the animal have airborne?
#
# Episode 4700, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have nlegs 4?
#  - Does the animal have toothed?
#  - Does the animal have predator?
#  - Does the animal have catsize?
#
# Episode 4750, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have airborne?
#  - Does the animal have tail?
#  - Does the animal have catsize?
#  - Does the animal have predator?
#
# Episode 4800, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have mammal?
#  - Does the animal have backbone?
#  - Does the animal have toothed?
#  - Does the animal have venomous?
#
# Episode 4850, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have breathes?
#  - Does the animal have feathers?
#  - Does the animal have hair?
#  - Does the animal have catsize?
#
# Episode 4900, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have mammal?
#  - Does the animal have toothed?
#  - Does the animal have toothed?
#  - Does the animal have feathers?
#
# Episode 4950, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have feathers?
#  - Does the animal have eggs?
#  - Does the animal have nlegs 2?
#  - Does the animal have breathes?
#  - Does the animal have insect?
#
# Episode 5000, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have nlegs 2?
#  - Does the animal have catsize?
#  - Does the animal have catsize?
#  - Does the animal have milk?
#  - Does the animal have toothed?
#
# Episode 5050, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have feathers?
#  - Does the animal have catsize?
#  - Does the animal have nlegs 4?
#  - Does the animal have hair?
#  - Does the animal have toothed?
#
# Episode 5100, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have mammal?
#  - Does the animal have backbone?
#  - Does the animal have mammal?
#  - Does the animal have toothed?
#
# Episode 5150, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have toothed?
#  - Does the animal have predator?
#  - Does the animal have tail?
#  - Does the animal have milk?
#  - Does the animal have hair?
#
# Episode 5200, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have mammal?
#  - Does the animal have tail?
#  - Does the animal have hair?
#  - Does the animal have hair?
#  - Does the animal have airborne?
#
# Episode 5250, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have breathes?
#  - Does the animal have domestic?
#  - Does the animal have bird?
#  - Does the animal have nlegs 2?
#
# Episode 5300, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have breathes?
#  - Does the animal have aquatic?
#  - Does the animal have eggs?
#  - Does the animal have milk?
#
# Episode 5350, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have feathers?
#  - Does the animal have domestic?
#  - Does the animal have hair?
#  - Does the animal have predator?
#  - Does the animal have predator?
#
# Episode 5400, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have predator?
#  - Does the animal have airborne?
#  - Does the animal have bird?
#  - Does the animal have airborne?
#
# Episode 5450, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have milk?
#  - Does the animal have aquatic?
#  - Does the animal have nlegs 2?
#  - Does the animal have toothed?
#
# Episode 5500, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have nlegs 4?
#  - Does the animal have aquatic?
#  - Does the animal have predator?
#  - Does the animal have tail?
#  - Does the animal have hair?
#
# Episode 5550, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have hair?
#  - Does the animal have aquatic?
#  - Does the animal have catsize?
#  - Does the animal have hair?
#  - Does the animal have predator?
#
# Episode 5600, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have nlegs 4?
#  - Does the animal have breathes?
#  - Does the animal have hair?
#  - Does the animal have bird?
#  - Does the animal have hair?
#
# Episode 5650, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have eggs?
#  - Does the animal have nlegs 2?
#  - Does the animal have predator?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 2?
#
# Episode 5700, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have mammal?
#  - Does the animal have airborne?
#  - Does the animal have tail?
#  - Does the animal have hair?
#  - Does the animal have airborne?
#
# Episode 5750, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have toothed?
#  - Does the animal have backbone?
#  - Does the animal have hair?
#  - Does the animal have hair?
#  - Does the animal have nlegs 2?
#
# Episode 5800, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have milk?
#  - Does the animal have feathers?
#  - Does the animal have domestic?
#  - Does the animal have toothed?
#
# Episode 5850, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have nlegs 2?
#  - Does the animal have eggs?
#  - Does the animal have backbone?
#  - Does the animal have toothed?
#
# Episode 5900, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have domestic?
#  - Does the animal have hair?
#  - Does the animal have backbone?
#  - Does the animal have airborne?
#
# Episode 5950, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have toothed?
#  - Does the animal have aquatic?
#  - Does the animal have predator?
#  - Does the animal have toothed?
#
# Episode 6000, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have toothed?
#  - Does the animal have nlegs 2?
#  - Does the animal have tail?
#  - Does the animal have breathes?
#
# Episode 6050, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have bird?
#  - Does the animal have catsize?
#  - Does the animal have tail?
#  - Does the animal have toothed?
#  - Does the animal have toothed?
#
# Episode 6100, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have nlegs 0?
#  - Does the animal have backbone?
#  - Does the animal have catsize?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 4?
#
# Episode 6150, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have domestic?
#  - Does the animal have nlegs 0?
#  - Does the animal have toothed?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 2?
#
# Episode 6200, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have predator?
#  - Does the animal have nlegs 0?
#  - Does the animal have toothed?
#  - Does the animal have aquatic?
#
# Episode 6250, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have aquatic?
#  - Does the animal have nlegs 0?
#  - Does the animal have backbone?
#  - Does the animal have catsize?
#
# Episode 6300, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have tail?
#  - Does the animal have nlegs 0?
#  - Does the animal have milk?
#  - Does the animal have eggs?
#
# Episode 6350, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have hair?
#  - Does the animal have nlegs 2?
#  - Does the animal have nlegs 0?
#  - Does the animal have aquatic?
#
# Episode 6400, Average Success Rate: 0.34
# Sample Questions:
#  - Does the animal have nlegs 0?
#  - Does the animal have hair?
#  - Does the animal have catsize?
#  - Does the animal have nlegs 2?
#  - Does the animal have breathes?
#
# Episode 6450, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have bird?
#  - Does the animal have toothed?
#  - Does the animal have toothed?
#  - Does the animal have toothed?
#  - Does the animal have nlegs 0?
#
# Episode 6500, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have hair?
#  - Does the animal have tail?
#  - Does the animal have catsize?
#  - Does the animal have feathers?
#
# Episode 6550, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have airborne?
#  - Does the animal have predator?
#  - Does the animal have nlegs 2?
#  - Does the animal have eggs?
#
# Episode 6600, Average Success Rate: 0.08
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have eggs?
#  - Does the animal have nlegs 2?
#  - Does the animal have hair?
#  - Does the animal have airborne?
#
# Episode 6650, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have catsize?
#  - Does the animal have catsize?
#  - Does the animal have feathers?
#  - Does the animal have hair?
#
# Episode 6700, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have bird?
#  - Does the animal have catsize?
#  - Does the animal have mammal?
#  - Does the animal have backbone?
#
# Episode 6750, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have mammal?
#  - Does the animal have hair?
#  - Does the animal have insect?
#  - Does the animal have mammal?
#  - Does the animal have milk?
#
# Episode 6800, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have nlegs 0?
#  - Does the animal have aquatic?
#  - Does the animal have breathes?
#  - Does the animal have eggs?
#  - Does the animal have tail?
#
# Episode 6850, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have predator?
#  - Does the animal have bird?
#  - Does the animal have nlegs 4?
#  - Does the animal have predator?
#
# Episode 6900, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have catsize?
#  - Does the animal have hair?
#  - Does the animal have tail?
#  - Does the animal have nlegs 0?
#
# Episode 6950, Average Success Rate: 0.08
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have breathes?
#  - Does the animal have breathes?
#  - Does the animal have eggs?
#  - Does the animal have fins?
#
# Episode 7000, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have nlegs 4?
#  - Does the animal have milk?
#  - Does the animal have breathes?
#  - Does the animal have nlegs 4?
#  - Does the animal have nlegs 4?
#
# Episode 7050, Average Success Rate: 0.30
# Sample Questions:
#  - Does the animal have hair?
#  - Does the animal have eggs?
#  - Does the animal have breathes?
#  - Does the animal have catsize?
#  - Does the animal have milk?
#
# Episode 7100, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have nlegs 0?
#  - Does the animal have airborne?
#  - Does the animal have nlegs 4?
#  - Does the animal have nlegs 2?
#  - Does the animal have backbone?
#
# Episode 7150, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have invertebrate?
#  - Does the animal have nlegs 0?
#  - Does the animal have milk?
#  - Does the animal have backbone?
#  - Does the animal have aquatic?
#
# Episode 7200, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have hair?
#  - Does the animal have tail?
#  - Does the animal have backbone?
#  - Does the animal have fins?
#
# Episode 7250, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have airborne?
#  - Does the animal have catsize?
#  - Does the animal have breathes?
#  - Does the animal have tail?
#
# Episode 7300, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have catsize?
#  - Does the animal have predator?
#  - Does the animal have tail?
#  - Does the animal have breathes?
#
# Episode 7350, Average Success Rate: 0.30
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have predator?
#  - Does the animal have breathes?
#  - Does the animal have predator?
#  - Does the animal have backbone?
#
# Episode 7400, Average Success Rate: 0.10
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have nlegs 4?
#  - Does the animal have domestic?
#  - Does the animal have nlegs 0?
#  - Does the animal have feathers?
#
# Episode 7450, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have hair?
#  - Does the animal have eggs?
#  - Does the animal have toothed?
#  - Does the animal have aquatic?
#  - Does the animal have mammal?
#
# Episode 7500, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have domestic?
#  - Does the animal have aquatic?
#  - Does the animal have eggs?
#  - Does the animal have predator?
#
# Episode 7550, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have nlegs 2?
#  - Does the animal have milk?
#  - Does the animal have backbone?
#  - Does the animal have mammal?
#  - Does the animal have predator?
#
# Episode 7600, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have mammal?
#  - Does the animal have milk?
#  - Does the animal have breathes?
#  - Does the animal have mammal?
#
# Episode 7650, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have fish?
#  - Does the animal have milk?
#  - Does the animal have domestic?
#  - Does the animal have milk?
#
# Episode 7700, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have hair?
#  - Does the animal have nlegs 4?
#  - Does the animal have milk?
#  - Does the animal have eggs?
#
# Episode 7750, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have mammal?
#  - Does the animal have nlegs 2?
#  - Does the animal have nlegs 2?
#  - Does the animal have toothed?
#  - Does the animal have feathers?
#
# Episode 7800, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have nlegs 0?
#  - Does the animal have nlegs 4?
#  - Does the animal have hair?
#  - Does the animal have eggs?
#
# Episode 7850, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have breathes?
#  - Does the animal have eggs?
#  - Does the animal have toothed?
#  - Does the animal have predator?
#
# Episode 7900, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have nlegs 0?
#  - Does the animal have catsize?
#  - Does the animal have hair?
#  - Does the animal have nlegs 0?
#  - Does the animal have backbone?
#
# Episode 7950, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have feathers?
#  - Does the animal have eggs?
#  - Does the animal have tail?
#  - Does the animal have breathes?
#
# Episode 8000, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have aquatic?
#  - Does the animal have backbone?
#  - Does the animal have milk?
#  - Does the animal have eggs?
#
# Episode 8050, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have nlegs 2?
#  - Does the animal have feathers?
#  - Does the animal have aquatic?
#  - Does the animal have airborne?
#  - Does the animal have eggs?
#
# Episode 8100, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have backbone?
#  - Does the animal have milk?
#  - Does the animal have catsize?
#  - Does the animal have aquatic?
#
# Episode 8150, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have nlegs 4?
#  - Does the animal have hair?
#  - Does the animal have tail?
#  - Does the animal have aquatic?
#
# Episode 8200, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have hair?
#  - Does the animal have airborne?
#  - Does the animal have milk?
#  - Does the animal have breathes?
#
# Episode 8250, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have mammal?
#  - Does the animal have aquatic?
#  - Does the animal have eggs?
#  - Does the animal have predator?
#  - Does the animal have tail?
#
# Episode 8300, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have toothed?
#  - Does the animal have airborne?
#  - Does the animal have tail?
#  - Does the animal have aquatic?
#  - Does the animal have hair?
#
# Episode 8350, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have tail?
#  - Does the animal have mammal?
#  - Does the animal have catsize?
#  - Does the animal have breathes?
#
# Episode 8400, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have nlegs 0?
#  - Does the animal have mammal?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 4?
#
# Episode 8450, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have tail?
#  - Does the animal have catsize?
#  - Does the animal have breathes?
#  - Does the animal have catsize?
#
# Episode 8500, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have feathers?
#  - Does the animal have nlegs 0?
#  - Does the animal have predator?
#  - Does the animal have backbone?
#  - Does the animal have backbone?
#
# Episode 8550, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have domestic?
#  - Does the animal have feathers?
#  - Does the animal have toothed?
#  - Does the animal have domestic?
#
# Episode 8600, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have hair?
#  - Does the animal have breathes?
#  - Does the animal have nlegs 2?
#  - Does the animal have domestic?
#  - Does the animal have airborne?
#
# Episode 8650, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have nlegs 4?
#  - Does the animal have airborne?
#  - Does the animal have eggs?
#  - Does the animal have eggs?
#
# Episode 8700, Average Success Rate: 0.08
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have nlegs 0?
#  - Does the animal have toothed?
#  - Does the animal have mammal?
#  - Does the animal have catsize?
#
# Episode 8750, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have domestic?
#  - Does the animal have toothed?
#  - Does the animal have toothed?
#  - Does the animal have backbone?
#
# Episode 8800, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have toothed?
#  - Does the animal have breathes?
#  - Does the animal have backbone?
#  - Does the animal have eggs?
#  - Does the animal have nlegs 4?
#
# Episode 8850, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have hair?
#  - Does the animal have breathes?
#  - Does the animal have aquatic?
#  - Does the animal have eggs?
#
# Episode 8900, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have mammal?
#  - Does the animal have backbone?
#  - Does the animal have aquatic?
#  - Does the animal have fish?
#
# Episode 8950, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have toothed?
#  - Does the animal have backbone?
#  - Does the animal have tail?
#  - Does the animal have eggs?
#  - Does the animal have toothed?
#
# Episode 9000, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have hair?
#  - Does the animal have nlegs 0?
#  - Does the animal have toothed?
#  - Does the animal have aquatic?
#  - Does the animal have backbone?
#
# Episode 9050, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have aquatic?
#  - Does the animal have breathes?
#  - Does the animal have breathes?
#  - Does the animal have mammal?
#
# Episode 9100, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have bird?
#  - Does the animal have hair?
#  - Does the animal have milk?
#  - Does the animal have tail?
#  - Does the animal have aquatic?
#
# Episode 9150, Average Success Rate: 0.44
# Sample Questions:
#  - Does the animal have nlegs 4?
#  - Does the animal have milk?
#  - Does the animal have mammal?
#  - Does the animal have nlegs 0?
#  - Does the animal have breathes?
#
# Episode 9200, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have nlegs 0?
#  - Does the animal have breathes?
#  - Does the animal have backbone?
#  - Does the animal have mammal?
#  - Does the animal have toothed?
#
# Episode 9250, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have airborne?
#  - Does the animal have nlegs 4?
#  - Does the animal have domestic?
#  - Does the animal have nlegs 0?
#
# Episode 9300, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have catsize?
#  - Does the animal have milk?
#  - Does the animal have backbone?
#  - Does the animal have reptile?
#
# Episode 9350, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have mammal?
#  - Does the animal have aquatic?
#  - Does the animal have aquatic?
#  - Does the animal have tail?
#
# Episode 9400, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have bird?
#  - Does the animal have backbone?
#  - Does the animal have tail?
#  - Does the animal have toothed?
#
# Episode 9450, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have airborne?
#  - Does the animal have milk?
#  - Does the animal have eggs?
#  - Does the animal have catsize?
#
# Episode 9500, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have eggs?
#  - Does the animal have catsize?
#  - Does the animal have aquatic?
#  - Does the animal have predator?
#
# Episode 9550, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have eggs?
#  - Does the animal have breathes?
#  - Does the animal have tail?
#  - Does the animal have venomous?
#
# Episode 9600, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have nlegs 4?
#  - Does the animal have tail?
#  - Does the animal have aquatic?
#  - Does the animal have predator?
#
# Episode 9650, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have toothed?
#  - Does the animal have eggs?
#  - Does the animal have breathes?
#  - Does the animal have predator?
#  - Does the animal have tail?
#
# Episode 9700, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have toothed?
#  - Does the animal have eggs?
#  - Does the animal have breathes?
#  - Does the animal have aquatic?
#  - Does the animal have hair?
#
# Episode 9750, Average Success Rate: 0.34
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have aquatic?
#  - Does the animal have invertebrate?
#  - Does the animal have backbone?
#  - Does the animal have fish?
#
# Episode 9800, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have eggs?
#  - Does the animal have nlegs 2?
#  - Does the animal have milk?
#  - Does the animal have feathers?
#  - Does the animal have breathes?
#
# Episode 9850, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have nlegs 2?
#  - Does the animal have breathes?
#  - Does the animal have eggs?
#  - Does the animal have tail?
#  - Does the animal have toothed?
#
# Episode 9900, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have tail?
#  - Does the animal have nlegs 4?
#  - Does the animal have aquatic?
#  - Does the animal have backbone?
#
# Episode 9950, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have mammal?
#  - Does the animal have nlegs 4?
#  - Does the animal have hair?
#  - Does the animal have toothed?
#
# Episode 10000, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have insect?
#  - Does the animal have predator?
#  - Does the animal have catsize?
#  - Does the animal have backbone?
#  - Does the animal have nlegs 2?
#
# Episode 10050, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have nlegs 2?
#  - Does the animal have feathers?
#  - Does the animal have feathers?
#  - Does the animal have catsize?
#  - Does the animal have catsize?
#
# Episode 10100, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have nlegs 0?
#  - Does the animal have nlegs 2?
#  - Does the animal have tail?
#  - Does the animal have catsize?
#  - Does the animal have predator?
#
# Episode 10150, Average Success Rate: 0.30
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have mammal?
#  - Does the animal have nlegs 2?
#  - Does the animal have breathes?
#  - Does the animal have predator?
#
# Episode 10200, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have aquatic?
#  - Does the animal have milk?
#  - Does the animal have eggs?
#  - Does the animal have fish?
#
# Episode 10250, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have airborne?
#  - Does the animal have tail?
#  - Does the animal have breathes?
#  - Does the animal have predator?
#
# Episode 10300, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have nlegs 4?
#  - Does the animal have hair?
#  - Does the animal have predator?
#  - Does the animal have eggs?
#  - Does the animal have airborne?
#
# Episode 10350, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have nlegs 0?
#  - Does the animal have airborne?
#  - Does the animal have tail?
#  - Does the animal have nlegs 0?
#  - Does the animal have catsize?
#
# Episode 10400, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have predator?
#  - Does the animal have backbone?
#  - Does the animal have catsize?
#  - Does the animal have toothed?
#
# Episode 10450, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have predator?
#  - Does the animal have eggs?
#  - Does the animal have mammal?
#  - Does the animal have backbone?
#
# Episode 10500, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have nlegs 2?
#  - Does the animal have tail?
#  - Does the animal have breathes?
#  - Does the animal have nlegs 0?
#  - Does the animal have backbone?
#
# Episode 10550, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have backbone?
#  - Does the animal have toothed?
#  - Does the animal have breathes?
#  - Does the animal have backbone?
#
# Episode 10600, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have toothed?
#  - Does the animal have airborne?
#  - Does the animal have breathes?
#  - Does the animal have feathers?
#  - Does the animal have toothed?
#
# Episode 10650, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have toothed?
#  - Does the animal have eggs?
#  - Does the animal have predator?
#  - Does the animal have invertebrate?
#
# Episode 10700, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have nlegs 0?
#  - Does the animal have milk?
#  - Does the animal have airborne?
#  - Does the animal have aquatic?
#
# Episode 10750, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have bird?
#  - Does the animal have eggs?
#  - Does the animal have aquatic?
#  - Does the animal have aquatic?
#  - Does the animal have breathes?
#
# Episode 10800, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have feathers?
#  - Does the animal have tail?
#  - Does the animal have backbone?
#  - Does the animal have aquatic?
#
# Episode 10850, Average Success Rate: 0.40
# Sample Questions:
#  - Does the animal have predator?
#  - Does the animal have eggs?
#  - Does the animal have hair?
#  - Does the animal have nlegs 0?
#  - Does the animal have airborne?
#
# Episode 10900, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have backbone?
#  - Does the animal have breathes?
#  - Does the animal have toothed?
#  - Does the animal have aquatic?
#
# Episode 10950, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have catsize?
#  - Does the animal have nlegs 4?
#  - Does the animal have nlegs 2?
#  - Does the animal have predator?
#
# Episode 11000, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have hair?
#  - Does the animal have nlegs 4?
#  - Does the animal have tail?
#  - Does the animal have nlegs 0?
#  - Does the animal have milk?
#
# Episode 11050, Average Success Rate: 0.34
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have catsize?
#  - Does the animal have tail?
#  - Does the animal have milk?
#  - Does the animal have toothed?
#
# Episode 11100, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have breathes?
#  - Does the animal have nlegs 4?
#  - Does the animal have milk?
#  - Does the animal have backbone?
#  - Does the animal have hair?
#
# Episode 11150, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have aquatic?
#  - Does the animal have nlegs 4?
#  - Does the animal have predator?
#  - Does the animal have milk?
#
# Episode 11200, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have tail?
#  - Does the animal have aquatic?
#  - Does the animal have backbone?
#  - Does the animal have tail?
#
# Episode 11250, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have eggs?
#  - Does the animal have hair?
#  - Does the animal have domestic?
#  - Does the animal have catsize?
#  - Does the animal have tail?
#
# Episode 11300, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have milk?
#  - Does the animal have backbone?
#  - Does the animal have hair?
#  - Does the animal have aquatic?
#
# Episode 11350, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have hair?
#  - Does the animal have mammal?
#  - Does the animal have aquatic?
#  - Does the animal have backbone?
#  - Does the animal have mammal?
#
# Episode 11400, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have backbone?
#  - Does the animal have milk?
#  - Does the animal have airborne?
#  - Does the animal have catsize?
#
# Episode 11450, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have aquatic?
#  - Does the animal have insect?
#  - Does the animal have invertebrate?
#  - Does the animal have backbone?
#
# Episode 11500, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have mammal?
#  - Does the animal have invertebrate?
#  - Does the animal have nlegs 2?
#  - Does the animal have backbone?
#
# Episode 11550, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have milk?
#  - Does the animal have catsize?
#  - Does the animal have nlegs 2?
#  - Does the animal have milk?
#  - Does the animal have milk?
#
# Episode 11600, Average Success Rate: 0.30
# Sample Questions:
#  - Does the animal have aquatic?
#  - Does the animal have hair?
#  - Does the animal have domestic?
#  - Does the animal have fish?
#  - Does the animal have venomous?
#
# Episode 11650, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have backbone?
#  - Does the animal have backbone?
#  - Does the animal have feathers?
#  - Does the animal have backbone?
#
# Episode 11700, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have predator?
#  - Does the animal have predator?
#  - Does the animal have aquatic?
#  - Does the animal have catsize?
#
# Episode 11750, Average Success Rate: 0.24
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have aquatic?
#  - Does the animal have milk?
#  - Does the animal have feathers?
#  - Does the animal have backbone?
#
# Episode 11800, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have domestic?
#  - Does the animal have bird?
#  - Does the animal have invertebrate?
#  - Does the animal have tail?
#  - Does the animal have feathers?
#
# Episode 11850, Average Success Rate: 0.18
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have aquatic?
#  - Does the animal have tail?
#  - Does the animal have insect?
#  - Does the animal have tail?
#
# Episode 11900, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have domestic?
#  - Does the animal have invertebrate?
#  - Does the animal have hair?
#  - Does the animal have backbone?
#  - Does the animal have feathers?
#
# Episode 11950, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have nlegs 2?
#  - Does the animal have catsize?
#  - Does the animal have invertebrate?
#  - Does the animal have aquatic?
#  - Does the animal have airborne?
#
# Episode 12000, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have airborne?
#  - Does the animal have airborne?
#  - Does the animal have hair?
#  - Does the animal have milk?
#
# Episode 12050, Average Success Rate: 0.12
# Sample Questions:
#  - Does the animal have feathers?
#  - Does the animal have backbone?
#  - Does the animal have mammal?
#  - Does the animal have milk?
#  - Does the animal have mammal?
#
# Episode 12100, Average Success Rate: 0.20
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have invertebrate?
#  - Does the animal have feathers?
#  - Does the animal have amphibian?
#  - Does the animal have hair?
#
# Episode 12150, Average Success Rate: 0.28
# Sample Questions:
#  - Does the animal have tail?
#  - Does the animal have nlegs 2?
#  - Does the animal have catsize?
#  - Does the animal have hair?
#  - Does the animal have nlegs 2?
#
# Episode 12200, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have insect?
#  - Does the animal have catsize?
#  - Does the animal have tail?
#  - Does the animal have backbone?
#  - Does the animal have backbone?
#
# Episode 12250, Average Success Rate: 0.14
# Sample Questions:
#  - Does the animal have catsize?
#  - Does the animal have hair?
#  - Does the animal have tail?
#  - Does the animal have backbone?
#  - Does the animal have aquatic?
#
# Episode 12300, Average Success Rate: 0.26
# Sample Questions:
#  - Does the animal have airborne?
#  - Does the animal have hair?
#  - Does the animal have bird?
#  - Does the animal have feathers?
#  - Does the animal have catsize?
#
# Episode 12350, Average Success Rate: 0.16
# Sample Questions:
#  - Does the animal have backbone?
#  - Does the animal have aquatic?
#  - Does the animal have catsize?
#  - Does the animal have tail?
#  - Does the animal have catsize?
#
# Episode 12400, Average Success Rate: 0.22
# Sample Questions:
#  - Does the animal have hair?
#  - Does the animal have tail?
#  - Does the animal have domestic?
#  - Does the animal have hair?
#  - Does the animal have fins?

# %%
plt.plot(np.convolve(success_log, np.ones(50)/50, mode='valid'))
plt.xlabel("Episode")
plt.ylabel("Success Rate (50-ep avg)")
plt.title("PPO Success Rate on Animal 20Q")
plt.grid(True)
plt.show()
